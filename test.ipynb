# %%
import pandas as pd

# %%
df = pd.read_parquet(r"D:\Lakehouse\lake_house_prj\part-00000-159d727c-3416-4fd2-9776-1e4660706cc6-c000.snappy.parquet")

# %%
print(df)
# Out:
#   ticker  price_start  price_end  growth_pct
# 0    VIC        11.48     166.80     1352.96
# 1    MWG         6.97      90.20     1194.12
# 2    MBB         2.87      27.70      865.16
# 3    HPG         3.15      28.50      804.76
# 4    ACB         2.98      24.00      705.37
# 5    SHB         1.94      15.50      698.97
# 6    VIB         2.41      16.95      603.32
# 7    STB        13.83      68.70      396.75
# 8    GAS        23.21     115.00      395.48
# 9    VCB        13.36      63.30      373.80
